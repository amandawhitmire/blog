# %% [markdown]
# ## 1. Downloading spaCy models
#
# The first step is to download the spaCy model. The model has been pre-trained on annotated English corpora. You only have to run these code cells below the first time you run the notebook; after that, you can skip right to step 2 and carry on from there. (If you run them again later, nothing bad will happen; it’ll just download again.) You can also run spaCy in other notebooks on your computer in the future, and you’ll be able to skip the step of downloading the models.

# %%
#Imports the module you need to download and install the spaCy models
import sys

# %%
#Installs the English spaCy model
# !{sys.executable} -m pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.1.0/en_core_web_trf-3.1.0.tar.gz

# %% [markdown]
# ## 2. Importing spaCy and setting up NLP
#
# Run the code cell below to import the spaCy module, and create a functions to loads the Englsih model and run the NLP algorithms (includes named-entity recognition).

# %%
#Imports spaCy
import spacy

#Imports the English model
import en_core_web_trf

# %% [markdown]
# ## 3. Importing other modules
#
# There’s various other modules that will be useful in this notebook. The code comments explain what each one is for. This code cell imports all of those.

# %%
#io is used for opening and writing files
import io

#glob is used to find all the pathnames matching a specified pattern (here, all text files)
import glob

#os is used to navigate your folder directories (e.g. change folders to where you files are stored)
import os

# for handling data frames, etc.
import pandas as pd

# Import the spaCy visualizer
from spacy import displacy

# Import the Entityt Ruler for making custom entities
from spacy.pipeline import EntityRuler

import datetime 

# pre-processing pipeline
import textacy
from textacy import preprocessing

# %% [markdown]
# ## 4. Diretory setup
#
# Assuming you’re running Jupyter Notebook from your computer’s home directory, this code cell gives you the opportunity to change directories, into the directory where you’re keeping your project files. I've put just a few of the ANSP volumes into a folder called `subset`.

# %%
#Define the file directory here
filedirectory = '/Users/thalassa/Rcode/blog/data/animals-clean/'

#Change the working directory to the one you just defined
os.chdir(filedirectory)

# %%
import nltk
from nltk import tokenize
from nltk.tokenize import word_tokenize, sent_tokenize
import json

# %%
with open('/Users/thalassa/Rcode/blog/data/animals-clean/44pg145-clean-taxa.txt', 'r') as f:
    text = f.read()

# %%
sentences = tokenize.sent_tokenize(text)

# %%
print(sentences)

# %%
def load_json_data(file):
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)
    return (data)

# %%
def load_text_data(file):
    with open(file, 'r') as f:
        text = f.read()
    return (text)

# %%
def create_tagged_sents(textfile, jsonfile):
    taxalist = load_json_data(jsonfile) 
    text = load_text_data(textfile)
    sentences_with_taxa = []
    for sen in sent_tokenize(text):
        l = word_tokenize(sen)
        if len(set(l).intersection(taxalist))>0:
            sentences_with_taxa.append(sen)
    return (sentences_with_taxa)

# %%
sent_with_taxa = create_tagged_sents("/Users/thalassa/Rcode/blog/data/animals-clean/44pg145-clean-taxa.txt", "/Users/thalassa/Rcode/blog/data/ansp-taxa-clean.json")

# %%
print(sent_with_taxa)

# %%
start = datetime.datetime.utcnow()
sent_out = []
#For each of those files...
for filename in sorted(os.listdir(filedirectory)):
    #If the filename ends with .txt (i.e. if it's actually a text files)
    if filename.endswith('.txt'):
        #Write out below the name of the file
        print(filename)
        #Open the infput filename
        sent_with_taxa = create_tagged_sents(filename, "/Users/thalassa/Rcode/blog/data/ansp-taxa-clean.json")
        sent_out = sent out + sent_with_taxa
        
end = datetime.datetime.utcnow()
print(f"Finished at {end}, total time {(end-start).seconds / 60.} minutes.")
# Out:
# 07sxx30-clean-taxa.txt
# 12sxx03-clean-taxa.txt
# 19sxx03-clean-taxa.txt
# 23sxx01-clean-taxa.txt
# 23sxx04-clean-taxa.txt
# 23sxx06-clean-taxa.txt
# 24sxx03-clean-taxa.txt
# 24sxx07-clean-taxa.txt
# 24sxx08-clean-taxa.txt
# 25sxx02-clean-taxa.txt
# 25sxx07-clean-taxa.txt
# 25sxx10-clean-taxa.txt
# 25sxx11-clean-taxa.txt
# 25sxx12-clean-taxa.txt
# 25sxx14-clean-taxa.txt
# 25sxx15-clean-taxa.txt
# 26sxx03-clean-taxa.txt
# 26sxx04-clean-taxa.txt
# 26sxx05-clean-taxa.txt
# 26sxx06-clean-taxa.txt
# 26sxx08-clean-taxa.txt
# 26sxx09-clean-taxa.txt
# 26sxx10-clean-taxa.txt
# 27sxx03-clean-taxa.txt
# 27sxx06-clean-taxa.txt
# 27sxx09-clean-taxa.txt
# 27sxx21-clean-taxa.txt
# 27sxx62-clean-taxa.txt
# 29sxx05-clean-taxa.txt
# 29sxx06-clean-taxa.txt
# 30sxx01-clean-taxa.txt
# 30sxx04-clean-taxa.txt
# 30sxx05-clean-taxa.txt
# 30sxx06-clean-taxa.txt
# 30sxx08-clean-taxa.txt
# 30sxx09-clean-taxa.txt
# 30sxx10-clean-taxa.txt
# 31sxx07-clean-taxa.txt
# 31sxx08-clean-taxa.txt
# 31sxx10-clean-taxa.txt
# 31sxx11-clean-taxa.txt
# 31sxx13-clean-taxa.txt
# 31sxx14-clean-taxa.txt
# 31sxx16-clean-taxa.txt
# 31sxx26-clean-taxa.txt
# 32sxx02-clean-taxa.txt
# 32sxx03-clean-taxa.txt
# 32sxx06-clean-taxa.txt
# 32sxx09-clean-taxa.txt
# 33sxx01-clean-taxa.txt
# 33sxx07-clean-taxa.txt
# 34sxx01-clean-taxa.txt
# 34sxx06-clean-taxa.txt
# 36sxx04-clean-taxa.txt
# 36sxx07-clean-taxa.txt
# 37sxx06-clean-taxa.txt
# 37sxx11-clean-taxa.txt
# 39sxx02-clean-taxa.txt
# 39sxx03-clean-taxa.txt
# 39sxx04-clean-taxa.txt
# 39sxx05-clean-taxa.txt
# 39sxx06-clean-taxa.txt
# 39sxx07-clean-taxa.txt
# 39sxx08-clean-taxa.txt
# 39sxx09-clean-taxa.txt
# 39sxx10-clean-taxa.txt
# 40sxx04-clean-taxa.txt
# 40sxx06-clean-taxa.txt
# 40sxx08-clean-taxa.txt
# 40sxx09-clean-taxa.txt
# 40sxx10-clean-taxa.txt
# 40sxx14-clean-taxa.txt
# 40sxx15-clean-taxa.txt
# 40sxx16-clean-taxa.txt
# 40sxx17-clean-taxa.txt
# 40sxx20-clean-taxa.txt
# 41sxx02-clean-taxa.txt
# 41sxx04-clean-taxa.txt
# 41sxx06-clean-taxa.txt
# 41sxx07-clean-taxa.txt
# 41sxx09-clean-taxa.txt
# 41sxx12-clean-taxa.txt
# 41sxx16-clean-taxa.txt
# 41sxx17-clean-taxa.txt
# 41sxx20-clean-taxa.txt
# 41sxx22-clean-taxa.txt
# 41sxx23-clean-taxa.txt
# 41sxx26-clean-taxa.txt
# 41sxx28-clean-taxa.txt
# 42sxx01-clean-taxa.txt
# 42sxx03-clean-taxa.txt
# 42sxx04-clean-taxa.txt
# 42sxx10-clean-taxa.txt
# 42sxx11-clean-taxa.txt
# 42sxx12-clean-taxa.txt
# 42sxx13-clean-taxa.txt
# 43sxx05-clean-taxa.txt
# 43sxx07-clean-taxa.txt
# 43sxx08-clean-taxa.txt
# 43sxx09-clean-taxa.txt
# 43sxx10-clean-taxa.txt
# 43sxx11-clean-taxa.txt
# 43sxx12-clean-taxa.txt
# 43sxx13-clean-taxa.txt
# 43sxx15-clean-taxa.txt
# 43sxx16-clean-taxa.txt
# 43sxx19-clean-taxa.txt
# 44PG357-clean-taxa.txt
# 44pg131-clean-taxa.txt
# 44pg133-clean-taxa.txt
# 44pg136-clean-taxa.txt
# 44pg142-clean-taxa.txt
# 44pg145-clean-taxa.txt
# 44pg156-clean-taxa.txt
# 44pg160-clean-taxa.txt
# 44pg169-clean-taxa.txt
# 44pg203-clean-taxa.txt
# 44pg213-clean-taxa.txt
# 44pg219-clean-taxa.txt
# 44pg230-clean-taxa.txt
# 44pg288-clean-taxa.txt
# 44pg291-clean-taxa.txt
# 44pg331-clean-taxa.txt
# 44pg338-clean-taxa.txt
# 44pg342-clean-taxa.txt
# 44pg387-clean-taxa.txt
# 44pg405-clean-taxa.txt
# 44sxx02-clean-taxa.txt
# 44sxx15-clean-taxa.txt
# 45sxx02-clean-taxa.txt
# 45sxx06-clean-taxa.txt
# 45sxx07-clean-taxa.txt
# 45sxx08-clean-taxa.txt
# 45sxx09-clean-taxa.txt
# 45sxx12-clean-taxa.txt
# 45sxx15-clean-taxa.txt
# 45sxx16-clean-taxa.txt
# 45sxx17-clean-taxa.txt
# 45sxx21-clean-taxa.txt
# 45sxx22-clean-taxa.txt
# 45sxx24-clean-taxa.txt
# 45sxx26-clean-taxa.txt
# 45sxx30-clean-taxa.txt
# 46sxx02-clean-taxa.txt
# 46sxx03-clean-taxa.txt
# 46sxx04-clean-taxa.txt
# 46sxx06-clean-taxa.txt
# 46sxx08-clean-taxa.txt
# 46sxx09-clean-taxa.txt
# 46sxx13-clean-taxa.txt
# 46sxx14-clean-taxa.txt
# 46sxx16-clean-taxa.txt
# 46sxx17-clean-taxa.txt
# 46sxx18-clean-taxa.txt
# 46sxx19-clean-taxa.txt
# 46sxx20-clean-taxa.txt
# 46sxx21-clean-taxa.txt
# 46sxx22-clean-taxa.txt
# 46sxx23-clean-taxa.txt
# 46sxx24-clean-taxa.txt
# 46sxx26-clean-taxa.txt
# 47sxx03-clean-taxa.txt
# 47sxx04-clean-taxa.txt
# 47sxx07-clean-taxa.txt
# 47sxx09-clean-taxa.txt
# 47sxx12-clean-taxa.txt
# 47sxx13-clean-taxa.txt
# 47sxx15-clean-taxa.txt
# 47sxx18-clean-taxa.txt
# 47sxx20-clean-taxa.txt
# 48sxx02-clean-taxa.txt
# 48sxx03-clean-taxa.txt
# 48sxx09-clean-taxa.txt
# 48sxx10-clean-taxa.txt
# 48sxx12-clean-taxa.txt
# 48sxx13-clean-taxa.txt
# 48sxx14-clean-taxa.txt
# 48sxx16-clean-taxa.txt
# 48sxx17-clean-taxa.txt
# 48sxx18-clean-taxa.txt
# 48sxx19-clean-taxa.txt
# 48sxx20-clean-taxa.txt
# 48sxx23-clean-taxa.txt
# 49sxx02-clean-taxa.txt
# 49sxx05-clean-taxa.txt
# 49sxx14-clean-taxa.txt
# 49sxx15-clean-taxa.txt
# 49sxx16-clean-taxa.txt
# 49sxx19-clean-taxa.txt
# 49sxx20-clean-taxa.txt
# 49sxx22-clean-taxa.txt
# 49sxx23-clean-taxa.txt
# 49sxx25-clean-taxa.txt
# 49sxx26-clean-taxa.txt
# 49sxx29-clean-taxa.txt
# 49sxx30-clean-taxa.txt
# 49sxx33-clean-taxa.txt
# 50sxx04-clean-taxa.txt
# 50sxx05-clean-taxa.txt
# 50sxx12-clean-taxa.txt
# 50sxx13-clean-taxa.txt
# 50sxx14-clean-taxa.txt
# 50sxx15-clean-taxa.txt
# 50sxx16-clean-taxa.txt
# 50sxx18-clean-taxa.txt
# 50sxx19-clean-taxa.txt
# 50sxx20-clean-taxa.txt
# 50sxx21-clean-taxa.txt
# 50sxx22-clean-taxa.txt
# 50sxx23-clean-taxa.txt
# 50sxx24-clean-taxa.txt
# 50sxx26-clean-taxa.txt
# 50sxx27-clean-taxa.txt
# 50sxx30-clean-taxa.txt
# 50sxx32-clean-taxa.txt
# 50sxx39-clean-taxa.txt
# 50sxx41-clean-taxa.txt
# 50sxx42-clean-taxa.txt
# 51sxx03-clean-taxa.txt
# 51sxx04-clean-taxa.txt
# 51sxx11-clean-taxa.txt
# 51sxx12-clean-taxa.txt
# 51sxx13-clean-taxa.txt
# 51sxx15-clean-taxa.txt
# 51sxx16-clean-taxa.txt
# 51sxx17-clean-taxa.txt
# 51sxx18-clean-taxa.txt
# 51sxx19-clean-taxa.txt
# 51sxx20-clean-taxa.txt
# 51sxx21-clean-taxa.txt
# 51sxx22-clean-taxa.txt
# 51sxx23-clean-taxa.txt
# 51sxx24-clean-taxa.txt
# 51sxx28-clean-taxa.txt
# 51sxx30-clean-taxa.txt
# 51sxx33-clean-taxa.txt
# 52sxx04-clean-taxa.txt
# 52sxx08-clean-taxa.txt
# 52sxx09-clean-taxa.txt
# 52sxx10-clean-taxa.txt
# 52sxx12-clean-taxa.txt
# 52sxx13-clean-taxa.txt
# 52sxx15-clean-taxa.txt
# 52sxx17-clean-taxa.txt
# 52sxx18-clean-taxa.txt
# 52sxx20-clean-taxa.txt
# 52sxx22-clean-taxa.txt
# 52sxx23-clean-taxa.txt
# 52sxx27-clean-taxa.txt
# 53sxx02-clean-taxa.txt
# 53sxx03-clean-taxa.txt
# 53sxx04-clean-taxa.txt
# 53sxx05-clean-taxa.txt
# 53sxx06-clean-taxa.txt
# 53sxx07-clean-taxa.txt
# 53sxx12-clean-taxa.txt
# 53sxx14-clean-taxa.txt
# 53sxx15-clean-taxa.txt
# 53sxx16-clean-taxa.txt
# 53sxx17-clean-taxa.txt
# 53sxx19-clean-taxa.txt
# 53sxx20-clean-taxa.txt
# 53sxx21-clean-taxa.txt
# 53sxx23-clean-taxa.txt
# 53sxx25-clean-taxa.txt
# 53sxx28-clean-taxa.txt
# 53sxx29-clean-taxa.txt
# 53sxx32-clean-taxa.txt
# 53sxx34-clean-taxa.txt
# 53sxx36-clean-taxa.txt
# 53sxx38-clean-taxa.txt
# 55sxx01-clean-taxa.txt
# 55sxx03-clean-taxa.txt
# 55sxx04-clean-taxa.txt
# 55sxx06-clean-taxa.txt
# 55sxx07-clean-taxa.txt
# 55sxx08-clean-taxa.txt
# 55sxx09-clean-taxa.txt
# 55sxx10-clean-taxa.txt
# 55sxx11-clean-taxa.txt
# 55sxx13-clean-taxa.txt
# 56sxx01-clean-taxa.txt
# 56sxx03-clean-taxa.txt
# 56sxx04-clean-taxa.txt
# 56sxx05-clean-taxa.txt
# 56sxx06-clean-taxa.txt
# 56sxx07-clean-taxa.txt
# 56sxx08-clean-taxa.txt
# 56sxx09-clean-taxa.txt
# 56sxx11-clean-taxa.txt
# 57sxx01-clean-taxa.txt
# 57sxx02-clean-taxa.txt
# 57sxx03-clean-taxa.txt
# 57sxx04-clean-taxa.txt
# 57sxx05-clean-taxa.txt
# 57sxx06-clean-taxa.txt
# 57sxx07-clean-taxa.txt
# 57sxx08-clean-taxa.txt
# 57sxx09-clean-taxa.txt
# 57sxx10-clean-taxa.txt
# 57sxx11-clean-taxa.txt
# 57sxx12-clean-taxa.txt
# 57sxx13-clean-taxa.txt
# 57sxx14-clean-taxa.txt
# 57sxx15-clean-taxa.txt
# 57sxx16-clean-taxa.txt
# 57sxx17-clean-taxa.txt
# 57sxx18-clean-taxa.txt
# 57sxx19-clean-taxa.txt
# 57sxx20-clean-taxa.txt
# 57sxx21-clean-taxa.txt
# 57sxx22-clean-taxa.txt
# 57sxx23-clean-taxa.txt
# 57sxx25-clean-taxa.txt
# 57sxx30-clean-taxa.txt
# 57sxx35-clean-taxa.txt
# 57sxx39-clean-taxa.txt
# 58sxx00-clean-taxa.txt
# 58sxx01-clean-taxa.txt
# 58sxx03-clean-taxa.txt
# 58sxx04-clean-taxa.txt
# 58sxx05-clean-taxa.txt
# 58sxx07-clean-taxa.txt
# 58sxx08-clean-taxa.txt
# 58sxx11-clean-taxa.txt
# 58sxx12-clean-taxa.txt
# 59sxx01-clean-taxa.txt
# 59sxx02-clean-taxa.txt
# 59sxx04-clean-taxa.txt
# 59sxx06-clean-taxa.txt
# 59sxx08-clean-taxa.txt
# 59sxx09-clean-taxa.txt
# 60sxx01-clean-taxa.txt
# 60sxx02-clean-taxa.txt
# 60sxx04-clean-taxa.txt
# 60sxx06-clean-taxa.txt
# 60sxx07-clean-taxa.txt
# 60sxx08-clean-taxa.txt
# 61sxx01-clean-taxa.txt
# 61sxx02-clean-taxa.txt
# 61sxx04-clean-taxa.txt
# 62sxx01-clean-taxa.txt
# 62sxx02-clean-taxa.txt
# 62sxx04-clean-taxa.txt
# 62sxx05-clean-taxa.txt
# 62sxx07-clean-taxa.txt
# 62sxx08-clean-taxa.txt
# 62sxx09-clean-taxa.txt
# 62sxx10-clean-taxa.txt
# 62sxx11-clean-taxa.txt
# 62sxx12-clean-taxa.txt
# 62sxx13-clean-taxa.txt
# 63sxx03-clean-taxa.txt
# 63sxx04-clean-taxa.txt
# 63sxx07-clean-taxa.txt
# 64sxx01-clean-taxa.txt
# 64sxx05-clean-taxa.txt
# 64sxx07-clean-taxa.txt
# 64sxx08-clean-taxa.txt
# 64sxx09-clean-taxa.txt
# 64sxx10-clean-taxa.txt
# 65sxx01-clean-taxa.txt
# 65sxx03-clean-taxa.txt
# 65sxx05-clean-taxa.txt
# 65sxx07-clean-taxa.txt
# 66sxx02-clean-taxa.txt
# 66sxx03-clean-taxa.txt
# 66sxx04-clean-taxa.txt
# 66sxx05-clean-taxa.txt
# 66sxx09-clean-taxa.txt
# 66sxx10-clean-taxa.txt
# 67sxx01-clean-taxa.txt
# 67sxx02-clean-taxa.txt
# 67sxx03-clean-taxa.txt
# 67sxx04-clean-taxa.txt
# 67sxx05-clean-taxa.txt
# 67sxx06-clean-taxa.txt
# 67sxx07-clean-taxa.txt
# 67sxx08-clean-taxa.txt
# 67sxx09-clean-taxa.txt
# 67sxx10-clean-taxa.txt
# 67sxx11-clean-taxa.txt
# 67sxx13-clean-taxa.txt
# 67sxx14-clean-taxa.txt
# 67sxx15-clean-taxa.txt
# 67sxx16-clean-taxa.txt
# 67sxx17-clean-taxa.txt
# 67sxx18-clean-taxa.txt
# 67sxx20-clean-taxa.txt
# 68sxx01-clean-taxa.txt
# 68sxx02-clean-taxa.txt
# 68sxx04-clean-taxa.txt
# 69sxx01-clean-taxa.txt
# 69sxx04-clean-taxa.txt
# 69sxx07-clean-taxa.txt
# 69sxx08-clean-taxa.txt
# 69sxx09-clean-taxa.txt
# 69sxx12-clean-taxa.txt
# 70sxx02-clean-taxa.txt
# 70sxx04-clean-taxa.txt
# 70sxx06-clean-taxa.txt
# 70sxx12-clean-taxa.txt
# 70sxx13-clean-taxa.txt
# 70sxx14-clean-taxa.txt
# 70sxx15-clean-taxa.txt
# 71sxx02-clean-taxa.txt
# 71sxx03-clean-taxa.txt
# 71sxx04-clean-taxa.txt
# 71sxx06-clean-taxa.txt
# 71sxx09-clean-taxa.txt
# 71sxx11-clean-taxa.txt
# 71sxx14-clean-taxa.txt
# 72sxx01-clean-taxa.txt
# 72sxx05-clean-taxa.txt
# 72sxx06-clean-taxa.txt
# 72sxx07-clean-taxa.txt
# 72sxx09-clean-taxa.txt
# 72sxx10-clean-taxa.txt
# 72sxx12-clean-taxa.txt
# 72sxx14-clean-taxa.txt
# 72sxx15-clean-taxa.txt
# 73sxx02-clean-taxa.txt
# 73sxx03-clean-taxa.txt
# 73sxx04-clean-taxa.txt
# 73sxx05-clean-taxa.txt
# 73sxx06-clean-taxa.txt
# 73sxx07-clean-taxa.txt
# 73sxx08-clean-taxa.txt
# 73sxx11-clean-taxa.txt
# 74sxx02-clean-taxa.txt
# 74sxx05-clean-taxa.txt
# animals-sxx03-clean-taxa.txt
# animals-sxx04-clean-taxa.txt
# animals-sxx05-clean-taxa.txt
# animals-sxx06-clean-taxa.txt
# animals-sxx07-clean-taxa.txt
# animals-sxx08-clean-taxa.txt
# animals-sxx09-clean-taxa.txt
# animals-sxx10-clean-taxa.txt
# animals-sxx11-clean-taxa.txt
# animals-sxx12-clean-taxa.txt
# animals-sxx13-clean-taxa.txt
# animals-sxx14-clean-taxa.txt
# animals-sxx15-clean-taxa.txt
# animals-sxx16-clean-taxa.txt
# animals-sxx17-clean-taxa.txt
# animals-sxx18-clean-taxa.txt
# animals-sxx19-clean-taxa.txt
# animals-sxx190-clean-taxa.txt
# animals-sxx20-clean-taxa.txt
# animals-sxx21-clean-taxa.txt
# animals-sxx22-clean-taxa.txt
# animals-sxx23-clean-taxa.txt
# animals-sxx24-clean-taxa.txt
# animals-sxx25-clean-taxa.txt
# animals-sxx26-clean-taxa.txt
# animals-sxx27-clean-taxa.txt
# animals-sxx28-clean-taxa.txt
# animals-sxx29-clean-taxa.txt
# animals-sxx30-clean-taxa.txt
# animals-sxx32-clean-taxa.txt
# animals-sxx33-clean-taxa.txt
# animals-sxx34-clean-taxa.txt
# animals-sxx35-clean-taxa.txt
# animals-sxx36-clean-taxa.txt
# animals-sxx38-clean-taxa.txt
# animals-sxx39-clean-taxa.txt
# animals-sxx41-clean-taxa.txt
# animals-sxx42-clean-taxa.txt
# animals-sxx62-clean-taxa.txt
# Finished at 2021-11-12 22:27:22.767798, total time 6.633333333333334 minutes.

# %%
with open('sentences_with_taxa.txt', 'w') as f:
    for item in sent_out:
        f.write("%s\n" % item)

# %%
type(sent_out)
# Out:
# list

# %%
preproc = preprocessing.make_pipeline(
    preprocessing.normalize.whitespace,
    preprocessing.normalize.hyphenated_words,
    preprocessing.normalize.unicode,
    preprocessing.normalize.quotation_marks,
    )

# %%
preproc("Frances Naomi Clark was an Amer-ican ichthyologist born in 1894, and was one of the first wom.an fishery researchers to receive world-wide recognition.  ")
# Out:
# 'Frances Naomi Clark was an Amer-ican ichthyologist born in 1894, and was one of the first wom.an fishery researchers to receive world-wide recognition.'

# %%
rows = []

for token in doc:
    rows.append(
        {
            'Token': token.text, 
            'Lemma': token.lemma_,
            'POS': token.pos_,
            'Tag': token.tag_,
            'Dependency': token.dep_,
            'Head': token.head,
            'Ent Type': token.ent_type_,
            'IsAlpha': token.is_alpha,
            'IsPunct': token.is_punct,
            'IsStop': token.is_stop
        }
    )   
tokes = pd.DataFrame(rows)

# %%
tokes.head(15)
# Out:
#             Token          Lemma    POS  Tag Dependency           Head  \
# 0         Frances        Frances  PROPN  NNP   compound          Clark
# 1           Naomi          Naomi  PROPN  NNP   compound          Clark
# 2           Clark          Clark  PROPN  NNP      nsubj            was
# 3             was             be    AUX  VBD       ROOT            was
# 4              an             an    DET   DT        det  ichthyologist
# 5        American       american    ADJ   JJ       amod  ichthyologist
# 6   ichthyologist  ichthyologist   NOUN   NN       attr            was
# 7            born           bear   VERB  VBN        acl  ichthyologist
# 8              in             in    ADP   IN       prep           born
# 9            1894           1894    NUM   CD       pobj             in
# 10              ,              ,  PUNCT    ,      punct            was
# 11            and            and  CCONJ   CC         cc            was
# 12            was             be   VERB  VBD       conj            was
# 13            one            one    NUM   CD       attr            was
# 14             of             of    ADP   IN       prep            one
#
#     Ent Type  IsAlpha  IsPunct  IsStop
# 0     PERSON     True    False   False
# 1     PERSON     True    False   False
# 2     PERSON     True    False   False
# 3                True    False    True
# 4                True    False    True
# 5       NORP     True    False   False
# 6                True    False   False
# 7                True    False   False
# 8                True    False    True
# 9       DATE    False    False   False
# 10              False     True   False
# 11               True    False    True
# 12               True    False    True
# 13  CARDINAL     True    False    True
# 14               True    False    True

# %% [markdown]
# ## Running spaCy
#
# This step will run every text file throught the complete spaCy pipeline
#
# ## Note - this takes a while - do not run this chunk unless you want to see the LOC results.

# %%
#Sort all the files in the directory you specified above, alphabetically.

start = datetime.datetime.utcnow()

#For each of those files...
for filename in sorted(os.listdir(filedirectory)):
    #If the filename ends with .txt (i.e. if it's actually a text files)
    if filename.endswith('.txt'):
        #Write out below the name of the file
        print(filename)
        #The file name of the output file adds _ner_loc to the end of the file name of the input file
        outfilename = filename.replace('.txt', '_nlp.txt')
        #Open the infput filename
        with open(filename, 'r') as f:
            #Create and open the output filename
            with open(outfilename, 'w') as out:
                #Read the contents of the input file
                voltext = f.read()
                #Do English NLP on the contents of the input file
                volner = nlp(voltext)
                #For each recognized entity
                rows = []
                for token in doc:
                    rows.append(
                        {
                            'Token': token.text, 
                            'Lemma': token.lemma_,
                            'POS': token.pos_,
                            'Tag': token.tag_,
                            'Dependency': token.dep_,
                            'Head': token.head,
                            'Ent Type': token.ent_type_,
                            'IsAlpha': token.is_alpha,
                            'IsPunct': token.is_punct,
                            'IsStop': token.is_stop
                        }
                    )   
                tokes = pd.DataFrame(rows)
                tokes.to_csv(outfilename, sep='\t', index = False, header=True)
                
end = datetime.datetime.utcnow()
print(f"Finished at {end}, total time {(end-start).seconds / 60.} minutes.")
# Out:
# 17669.txt
