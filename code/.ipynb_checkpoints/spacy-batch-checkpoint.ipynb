# %% [markdown]
# # Running spaCy on the corpus of the Proceedings of the Academy of Natural Sciences of Philadelphia (ANSP).
#
# The setup blocks for this notebook are adapted from portions of The Datasitter's Club, specifically, this Notebook:
#
# Skallerup Bessette, Lee and Quinn Quinn. “DSC Multilingual Mystery 2: Beware, Lee and Quinn!”. February 27, 2020. https://datasittersclub.github.io/site/dscm2.html.
#
# I am so grateful for the work that Quinn so generously documents and shares openly.

# %% [markdown]
# ## 1. Downloading spaCy models
#
# The first step is to download the spaCy model. The model has been pre-trained on annotated English corpora. You only have to run these code cells below the first time you run the notebook; after that, you can skip right to step 2 and carry on from there. (If you run them again later, nothing bad will happen; it’ll just download again.) You can also run spaCy in other notebooks on your computer in the future, and you’ll be able to skip the step of downloading the models.

# %%
#Imports the module you need to download and install the spaCy models
import sys

# %%
#Installs the English spaCy model
# !{sys.executable} -m pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.1.0/en_core_web_trf-3.1.0.tar.gz

# %% [markdown]
# ## 2. Importing spaCy and setting up NLP
#
# Run the code cell below to import the spaCy module, and create a functions to loads the Englsih model and run the NLP algorithms (includes named-entity recognition).

# %%
#Imports spaCy
import spacy

#Imports the English model
import en_core_web_trf

# %% [markdown]
# ## 3. Importing other modules
#
# There’s various other modules that will be useful in this notebook. The code comments explain what each one is for. This code cell imports all of those.

# %%
#io is used for opening and writing files
import io

#glob is used to find all the pathnames matching a specified pattern (here, all text files)
import glob

#os is used to navigate your folder directories (e.g. change folders to where you files are stored)
import os

# for handling data frames, etc.
import pandas as pd

# Import the spaCy visualizer
from spacy import displacy

# Import the Entityt Ruler for making custom entities
from spacy.pipeline import EntityRuler

import datetime 

# pre-processing pipeline
import textacy
from textacy import preprocessing

# %% [markdown]
# ## 4. Diretory setup
#
# Assuming you’re running Jupyter Notebook from your computer’s home directory, this code cell gives you the opportunity to change directories, into the directory where you’re keeping your project files. I've put just a few of the ANSP volumes into a folder called `subset`.

# %%
#Define the file directory here
filedirectory = '/Users/thalassa/Rcode/blog/data/pants/'

#Change the working directory to the one you just defined
os.chdir(filedirectory)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/5g/3v18ylv549z8z19q_rfdm_5c0000gq/T/ipykernel_7438/2909114586.py in <module>
#       3
#       4 #Change the working directory to the one you just defined
# ----> 5 os.chdir(filedirectory)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/thalassa/Rcode/blog/data/pants/'

# %%
#Sets up a function so you can run the English model on texts
nlp = en_core_web_trf.load()

#add the custom entity set (habitats ans taxonomic names)
ruler = nlp.add_pipe("entity_ruler", before='ner')

# this is a large entity set - it takes a while to load.
ruler.from_disk("/Users/thalassa/streamlit/streamlit-ansp/data/ansp-patterns.jsonl")

# %% [markdown]
# ## Run code on a single file to see how it works.

# %%
text = "Frances Naomi Clark was an American ichthyologist born in 1894, and was one of the first woman fishery researchers to receive world-wide recognition. Frances Naomi Clark was an American ichthyologist born in 1894, and was one of the first woman fishery researchers to receive world-wide recognition. Seven Ampelis cedrorum specimens were collected in a meadow near lowland fruit trees. Some habitats we know are in the json file are near large rocks, near river mouths, near the bottom and near the ocean. Some species names are Hemigrapsus affinis, Hemigrapsus crassimanus, Hendersonia alternifoliae and Hendersonia celtifolia."
doc = nlp(text)

# %%
rows = []

for token in doc:
    rows.append(
        {
            'Token': token.text, 
            'Lemma': token.lemma_,
            'POS': token.pos_,
            'Tag': token.tag_,
            'Dependency': token.dep_,
            'Head': token.head,
            'Ent Type': token.ent_type_,
            'IsAlpha': token.is_alpha,
            'IsPunct': token.is_punct,
            'IsStop': token.is_stop
        }
    )   
tokes = pd.DataFrame(rows)

# %%
tokes.head(15)
# Out:
#             Token          Lemma    POS  Tag Dependency           Head  \
# 0         Frances        Frances  PROPN  NNP   compound          Clark
# 1           Naomi          Naomi  PROPN  NNP   compound          Clark
# 2           Clark          Clark  PROPN  NNP      nsubj            was
# 3             was             be    AUX  VBD       ROOT            was
# 4              an             an    DET   DT        det  ichthyologist
# 5        American       american    ADJ   JJ       amod  ichthyologist
# 6   ichthyologist  ichthyologist   NOUN   NN       attr            was
# 7            born           bear   VERB  VBN        acl  ichthyologist
# 8              in             in    ADP   IN       prep           born
# 9            1894           1894    NUM   CD       pobj             in
# 10              ,              ,  PUNCT    ,      punct            was
# 11            and            and  CCONJ   CC         cc            was
# 12            was             be   VERB  VBD       conj            was
# 13            one            one    NUM   CD       attr            was
# 14             of             of    ADP   IN       prep            one
#
#     Ent Type  IsAlpha  IsPunct  IsStop
# 0     PERSON     True    False   False
# 1     PERSON     True    False   False
# 2     PERSON     True    False   False
# 3                True    False    True
# 4                True    False    True
# 5       NORP     True    False   False
# 6                True    False   False
# 7                True    False   False
# 8                True    False    True
# 9       DATE    False    False   False
# 10              False     True   False
# 11               True    False    True
# 12               True    False    True
# 13  CARDINAL     True    False    True
# 14               True    False    True

# %% [markdown]
# ## Running spaCy
#
# This step will run every text file throught the complete spaCy pipeline
#
# ## Note - this takes a while - do not run this chunk unless you want to see the LOC results.

# %%
print(os.listdir(filedirectory))
# Out:
# ['48sxx10.txt', '55sxx01.txt', '51sxx23.txt', '50sxx23.txt', 'animals-sxx33.txt', '64sxx09.txt', 'animals-sxx27.txt', '34sxx06.txt', '46sxx19.txt', '43sxx13.txt', '43sxx07.txt', '42sxx13.txt', '42sxx12.txt', '43sxx12.txt', '46sxx24.txt', '46sxx18.txt', '47sxx18.txt', 'animals-sxx26.txt', '64sxx08.txt', 'animals-sxx32.txt', '50sxx22.txt', '51sxx22.txt', '23sxx01.txt', '61sxx02.txt', '60sxx02.txt', '49sxx05.txt', '48sxx13.txt', '27sxx21.txt', '27sxx09.txt', '26sxx09.txt', '50sxx20.txt', '51sxx20.txt', 'animals-sxx24.txt', 'animals-sxx30.txt', 'animals-sxx18.txt', '46sxx26.txt', '42sxx10.txt', '43sxx10.txt', '42sxx04.txt', '43sxx11.txt', '42sxx11.txt', '43sxx05.txt', '31sxx26.txt', '44pg213.txt', 'animals-sxx19.txt', 'animals-sxx25.txt', '51sxx21.txt', '50sxx21.txt', '26sxx08.txt', '55sxx03.txt', '60sxx01.txt', '48sxx12.txt', '61sxx01.txt', '49sxx16.txt', '48sxx02.txt', '48sxx16.txt', '49sxx02.txt', '55sxx07.txt', '55sxx13.txt', '44pg405.txt', '50sxx19.txt', '23sxx06.txt', '51sxx19.txt', 'animals-sxx09.txt', 'animals-sxx21.txt', 'animals-sxx35.txt', '44pg203.txt', '46sxx23.txt', '72sxx09.txt', '29sxx05.txt', '.DS_Store', '42sxx01.txt', '43sxx15.txt', '73sxx08.txt', '34sxx01.txt', '46sxx22.txt', 'animals-sxx34.txt', 'animals-sxx20.txt', 'animals-sxx08.txt', '51sxx18.txt', '50sxx18.txt', '51sxx24.txt', '50sxx30.txt', '50sxx24.txt', '51sxx30.txt', '55sxx06.txt', '48sxx17.txt', '44pg160.txt', '60sxx04.txt', '48sxx03.txt', '61sxx04.txt', '60sxx06.txt', '49sxx15.txt', '49sxx29.txt', '55sxx10.txt', '55sxx04.txt', '50sxx32.txt', '50sxx26.txt', 'animals-sxx36.txt', 'animals-sxx22.txt', '47sxx20.txt', '46sxx20.txt', '46sxx08.txt', '29sxx06.txt', '43sxx16.txt', '30sxx09.txt', '31sxx08.txt', '42sxx03.txt', '30sxx08.txt', '47sxx09.txt', '46sxx09.txt', '46sxx21.txt', 'animals-sxx23.txt', '23sxx04.txt', '51sxx33.txt', '50sxx27.txt', '55sxx11.txt', '49sxx14.txt', '60sxx07.txt', '48sxx14.txt', '57sxx25.txt', '57sxx19.txt', '25sxx12.txt', '39sxx03.txt', '67sxx11.txt', '66sxx05.txt', '67sxx05.txt', '53sxx07.txt', '52sxx13.txt', '59sxx04.txt', '58sxx04.txt', '71sxx03.txt', '45sxx15.txt', '44sxx15.txt', '41sxx23.txt', '33sxx01.txt', '41sxx22.txt', '71sxx02.txt', '58sxx05.txt', '58sxx11.txt', '70sxx02.txt', '53sxx06.txt', '52sxx12.txt', '53sxx12.txt', '50sxx41.txt', '66sxx10.txt', '67sxx04.txt', '67sxx10.txt', '66sxx04.txt', '39sxx02.txt', '25sxx07.txt', '57sxx18.txt', '24sxx07.txt', '57sxx30.txt', '25sxx11.txt', '67sxx06.txt', '52sxx10.txt', '53sxx04.txt', '52sxx04.txt', '53sxx38.txt', '58sxx07.txt', '70sxx14.txt', '71sxx14.txt', '45sxx02.txt', '45sxx16.txt', '44sxx02.txt', '40sxx20.txt', '41sxx20.txt', '32sxx03.txt', '40sxx08.txt', '40sxx09.txt', '32sxx02.txt', '41sxx09.txt', '45sxx17.txt', '59sxx06.txt', '58sxx12.txt', '70sxx15.txt', '53sxx05.txt', '50sxx42.txt', '44pg338.txt', '67sxx13.txt', '67sxx07.txt', '25sxx10.txt', '25sxx14.txt', '57sxx23.txt', '62sxx09.txt', '39sxx05.txt', '67sxx03.txt', '67sxx17.txt', '66sxx03.txt', '53sxx29.txt', 'animals-sxx42.txt', '52sxx15.txt', '53sxx15.txt', '71sxx11.txt', '59sxx02.txt', '45sxx07.txt', '32sxx06.txt', '33sxx07.txt', '45sxx12.txt', '45sxx06.txt', '70sxx04.txt', '71sxx04.txt', '58sxx03.txt', '53sxx14.txt', '53sxx28.txt', '67sxx16.txt', '66sxx02.txt', '67sxx02.txt', '39sxx04.txt', '62sxx08.txt', '39sxx10.txt', '57sxx22.txt', '25sxx15.txt', '56sxx08.txt', '24sxx03.txt', '57sxx08.txt', '57sxx20.txt', '39sxx06.txt', '67sxx14.txt', 'whole_volumes', '53sxx16.txt', 'animals-sxx41.txt', '53sxx02.txt', '70sxx06.txt', '59sxx01.txt', '58sxx01.txt', '71sxx06.txt', '70sxx12.txt', '44pg288.txt', '69sxx09.txt', '41sxx26.txt', '69sxx08.txt', '58sxx00.txt', '70sxx13.txt', '52sxx17.txt', '53sxx03.txt', '53sxx17.txt', '67sxx01.txt', '67sxx15.txt', '39sxx07.txt', '57sxx35.txt', '57sxx21.txt', '57sxx09.txt', '25sxx02.txt', '56sxx09.txt', '57sxx04.txt', '56sxx04.txt', '57sxx10.txt', '44pg131.txt', '62sxx12.txt', '67sxx18.txt', '53sxx32.txt', '45sxx08.txt', '41sxx02.txt', '40sxx16.txt', '32sxx09.txt', '41sxx16.txt', '69sxx04. ...

# %%
#Sort all the files in the directory you specified above, alphabetically.

start = datetime.datetime.utcnow()

#For each of those files...
for filename in sorted(os.listdir(filedirectory)):
    #If the filename ends with .txt (i.e. if it's actually a text files)
    if filename.endswith('.txt'):
        #Write out below the name of the file
        print(filename)
        #The file name of the output file adds _ner_loc to the end of the file name of the input file
        outfilename = filename.replace('.txt', '_00_nlp.txt')
        #Open the infput filename
        with open(filename, 'r') as f:
            #Create and open the output filename
            with open(outfilename, 'w') as out:
                #Read the contents of the input file
                voltext = f.read()
                #Do English NLP on the contents of the input file
                volner = nlp(voltext)
                #For each recognized entity
                rows = []
                for token in volner:
                    rows.append(
                        {
                            'Token': token.text, 
                            'Lemma': token.lemma_,
                            'POS': token.pos_,
                            'Tag': token.tag_,
                            'Dependency': token.dep_,
                            'Head': token.head,
                            'Ent Type': token.ent_type_,
                            'IsAlpha': token.is_alpha,
                            'IsPunct': token.is_punct,
                            'IsStop': token.is_stop
                        }
                    )   
                tokes = pd.DataFrame(rows)
                tokes.to_csv(outfilename, sep='\t', index = False, header=True)
                
end = datetime.datetime.utcnow()
print(f"Finished at {end}, total time {(end-start).seconds / 60.} minutes.")
# Out:
# 07sxx30.txt
# 12sxx03.txt
# 19sxx03.txt
# 23sxx01.txt
# 23sxx04.txt
# 23sxx06.txt
# 24sxx03.txt
# 24sxx07.txt
# 24sxx08.txt
# 25sxx02.txt
# 25sxx07.txt
# 25sxx10.txt
# 25sxx11.txt
# 25sxx12.txt
# 25sxx14.txt
# 25sxx15.txt
# 26sxx03.txt
# 26sxx04.txt
# 26sxx05.txt
# 26sxx06.txt
# 26sxx08.txt
# 26sxx09.txt
# 26sxx10.txt
# 27sxx03.txt
# 27sxx06.txt
# 27sxx09.txt
# 27sxx21.txt
# 27sxx62.txt
# 29sxx05.txt
# 29sxx06.txt
# 30sxx01.txt
# 30sxx04.txt
# 30sxx05.txt
# 30sxx06.txt
# 30sxx08.txt
# 30sxx09.txt
# 30sxx10.txt
# 31sxx07.txt
# 31sxx08.txt
# 31sxx10.txt
# 31sxx11.txt
# 31sxx13.txt
# 31sxx14.txt
# 31sxx16.txt
# 31sxx26.txt
# 32sxx02.txt
# 32sxx03.txt
# 32sxx06.txt
# 32sxx09.txt
# 33sxx01.txt
# 33sxx07.txt
# 34sxx01.txt
# 34sxx06.txt
# 36sxx04.txt
# 36sxx07.txt
# 37sxx06.txt
# 37sxx11.txt
# 39sxx02.txt
# 39sxx03.txt
# 39sxx04.txt
# 39sxx05.txt
# 39sxx06.txt
# 39sxx07.txt
# 39sxx08.txt
# 39sxx09.txt
# 39sxx10.txt
# 40sxx04.txt
# 40sxx06.txt
# 40sxx08.txt
# 40sxx09.txt
# 40sxx10.txt
# 40sxx14.txt
# 40sxx15.txt
# 40sxx16.txt
# 40sxx17.txt
# 40sxx20.txt
# 41sxx02.txt
# 41sxx04.txt
# 41sxx06.txt
# 41sxx07.txt
# 41sxx09.txt
# 41sxx12.txt
# 41sxx16.txt
# 41sxx17.txt
# 41sxx20.txt
# 41sxx22.txt
# 41sxx23.txt
# 41sxx26.txt
# 41sxx28.txt
# 42sxx01.txt
# 42sxx03.txt
# 42sxx04.txt
# 42sxx10.txt
# 42sxx11.txt
# 42sxx12.txt
# 42sxx13.txt
# 43sxx05.txt
# 43sxx07.txt
# 43sxx08.txt
# 43sxx09.txt
# 43sxx10.txt
# 43sxx11.txt
# 43sxx12.txt
# 43sxx13.txt
# 43sxx15.txt
# 43sxx16.txt
# 43sxx19.txt
# 44PG357.txt
# 44pg131.txt
# 44pg133.txt
# 44pg136.txt
# 44pg142.txt
# 44pg145.txt
# 44pg156.txt
# 44pg160.txt
# 44pg169.txt
# 44pg203.txt
# 44pg213.txt
# 44pg219.txt
# 44pg230.txt
# 44pg288.txt
# 44pg291.txt
# 44pg331.txt
# 44pg338.txt
# 44pg342.txt
# 44pg387.txt
# 44pg405.txt
# 44sxx02.txt
# 44sxx15.txt
# 45sxx02.txt
# 45sxx06.txt
# 45sxx07.txt
# 45sxx08.txt
# 45sxx09.txt
# 45sxx12.txt
# 45sxx15.txt
# 45sxx16.txt
# 45sxx17.txt
# 45sxx21.txt
# 45sxx22.txt
# 45sxx24.txt
# 45sxx26.txt
# 45sxx30.txt
# 46sxx02.txt
# 46sxx03.txt
# 46sxx04.txt
# 46sxx06.txt
# 46sxx08.txt
# 46sxx09.txt
# 46sxx13.txt
# 46sxx14.txt
# 46sxx16.txt
# 46sxx17.txt
# 46sxx18.txt
# 46sxx19.txt
# 46sxx20.txt
# 46sxx21.txt
# 46sxx22.txt
# 46sxx23.txt
# 46sxx24.txt
# 46sxx26.txt
# 47sxx03.txt
# 47sxx04.txt
# 47sxx07.txt
# 47sxx09.txt
# 47sxx12.txt
# 47sxx13.txt
# 47sxx15.txt
# 47sxx18.txt
# 47sxx20.txt
# 48sxx02.txt
# 48sxx03.txt
# 48sxx09.txt
# 48sxx10.txt
# 48sxx12.txt
# 48sxx13.txt
# 48sxx14.txt
# 48sxx16.txt
# 48sxx17.txt
# 48sxx18.txt
# 48sxx19.txt
# 48sxx20.txt
# 48sxx23.txt
# 49sxx02.txt
# 49sxx05.txt
# 49sxx14.txt
# 49sxx15.txt
# 49sxx16.txt
# 49sxx19.txt
# 49sxx20.txt
# 49sxx22.txt
# 49sxx23.txt
# 49sxx25.txt
# 49sxx26.txt
# 49sxx29.txt
# 49sxx30.txt
# 49sxx33.txt
# 50sxx04.txt
# 50sxx05.txt
# 50sxx12.txt
# 50sxx13.txt
# 50sxx14.txt
# 50sxx15.txt
# 50sxx16.txt
# 50sxx18.txt
# 50sxx19.txt
# 50sxx20.txt
# 50sxx21.txt
# 50sxx22.txt
# 50sxx23.txt
# 50sxx24.txt
# 50sxx26.txt
# 50sxx27.txt
# 50sxx30.txt
# 50sxx32.txt
# 50sxx39.txt
# 50sxx41.txt
# 50sxx42.txt
# 51sxx03.txt
# 51sxx04.txt
# 51sxx11.txt
# 51sxx12.txt
# 51sxx13.txt
# 51sxx15.txt
# 51sxx16.txt
# 51sxx17.txt
# 51sxx18.txt
# 51sxx19.txt
# 51sxx20.txt
# 51sxx21.txt
# 51sxx22.txt
# 51sxx23.txt
# 51sxx24.txt
# 51sxx28.txt
# 51sxx30.txt
# 51sxx33.txt
# 52sxx04.txt
# 52sxx08.txt
# 52sxx09.txt
# 52sxx10.txt
# 52sxx12.txt
# 52sxx13.txt
# 52sxx15.txt
# 52sxx17.txt
# 52sxx18.txt
# 52sxx20.txt
# 52sxx22.txt
# 52sxx23.txt
# 52sxx27.txt
# 53sxx02.txt
# 53sxx03.txt
# 53sxx04.txt
# 53sxx05.txt
# 53sxx06.txt
# 53sxx07.txt
# 53sxx12.txt
# 53sxx14.txt
# 53sxx15.txt
# 53sxx16.txt
# 53sxx17.txt
# 53sxx19.txt
# 53sxx20.txt
# 53sxx21.txt
# 53sxx23.txt
# 53sxx25.txt
# 53sxx28.txt
# 53sxx29.txt
# 53sxx32.txt
# 53sxx34.txt
# 53sxx36.txt
# 53sxx38.txt
# 55sxx01.txt
# 55sxx03.txt
# 55sxx04.txt
# 55sxx06.txt
# 55sxx07.txt
# 55sxx08.txt
# 55sxx09.txt
# 55sxx10.txt
# 55sxx11.txt
# 55sxx13.txt
# 56sxx01.txt
# 56sxx03.txt
# 56sxx04.txt
# 56sxx05.txt
# 56sxx06.txt
# 56sxx07.txt
# 56sxx08.txt
# 56sxx09.txt
# 56sxx11.txt
# 57sxx01.txt
# 57sxx02.txt
# 57sxx03.txt
# 57sxx04.txt
# 57sxx05.txt
# 57sxx06.txt
# 57sxx07.txt
# 57sxx08.txt
# 57sxx09.txt
# 57sxx10.txt
# 57sxx11.txt
# 57sxx12.txt
# 57sxx13.txt
# 57sxx14.txt
# 57sxx15.txt
# 57sxx16.txt
# 57sxx17.txt
# 57sxx18.txt
# 57sxx19.txt
# 57sxx20.txt
# 57sxx21.txt
# 57sxx22.txt
# 57sxx23.txt
# 57sxx25.txt
# 57sxx30.txt
# 57sxx35.txt
# 57sxx39.txt
# 58sxx00.txt
# 58sxx01.txt
# 58sxx03.txt
# 58sxx04.txt
# 58sxx05.txt
# 58sxx07.txt
# 58sxx08.txt
# 58sxx11.txt
# 58sxx12.txt
# 59sxx01.txt
# 59sxx02.txt
# 59sxx04.txt
# 59sxx06.txt
# 59sxx08.txt
# 59sxx09.txt
# 60sxx01.txt
# 60sxx02.txt
# 60sxx04.txt
# 60sxx06.txt
# 60sxx07.txt
# 60sxx08.txt
# 61sxx01.txt
# 61sxx02.txt
# 61sxx04.txt
# 62sxx01.txt
# 62sxx02.txt
# 62sxx04.txt
# 62sxx05.txt
# 62sxx07.txt
# 62sxx08.txt
# 62sxx09.txt
# 62sxx10.txt
# 62sxx11.txt
# 62sxx12.txt
# 62sxx13.txt
# 63sxx03.txt
# 63sxx04.txt
# 63sxx07.txt
# 64sxx01.txt
# 64sxx05.txt
# 64sxx07.txt
# 64sxx08.txt
# 64sxx09.txt
# 64sxx10.txt
# 65sxx01.txt
# 65sxx03.txt
# 65sxx05.txt
# 65sxx07.txt
# 66sxx02.txt
# 66sxx03.txt
# 66sxx04.txt
# 66sxx05.txt
# 66sxx09.txt
# 66sxx10.txt
# 67sxx01.txt
# 67sxx02.txt
# 67sxx03.txt
# 67sxx04.txt
# 67sxx05.txt
# 67sxx06.txt
# 67sxx07.txt
# 67sxx08.txt
# 67sxx09.txt
# 67sxx10.txt
# 67sxx11.txt
# 67sxx13.txt
# 67sxx14.txt
# 67sxx15.txt
# 67sxx16.txt
# 67sxx17.txt
# 67sxx18.txt
# 67sxx20.txt
# 68sxx01.txt
# 68sxx02.txt
# 68sxx04.txt
# 69sxx01.txt
# 69sxx04.txt
# 69sxx07.txt
# 69sxx08.txt
# 69sxx09.txt
# 69sxx12.txt
# 70sxx02.txt
# 70sxx04.txt
# 70sxx06.txt
# 70sxx12.txt
# 70sxx13.txt
# 70sxx14.txt
# 70sxx15.txt
# 71sxx02.txt
# 71sxx03.txt
# 71sxx04.txt
# 71sxx06.txt
# 71sxx09.txt
# 71sxx11.txt
# 71sxx14.txt
# 72sxx01.txt
# 72sxx05.txt
# 72sxx06.txt
# 72sxx07.txt
# 72sxx09.txt
# 72sxx10.txt
# 72sxx12.txt
# 72sxx14.txt
# 72sxx15.txt
# 73sxx02.txt
# 73sxx03.txt
# 73sxx04.txt
# 73sxx05.txt
# 73sxx06.txt
# 73sxx07.txt
# 73sxx08.txt
# 73sxx11.txt
# 74sxx02.txt
# 74sxx05.txt
# animals-sxx03.txt
# animals-sxx04.txt
# animals-sxx05.txt
# animals-sxx06.txt
# animals-sxx07.txt
# animals-sxx08.txt
# animals-sxx09.txt
# animals-sxx10.txt
# animals-sxx11.txt
# animals-sxx12.txt
# animals-sxx13.txt
# animals-sxx14.txt
# animals-sxx15.txt
# animals-sxx16.txt
# animals-sxx17.txt
# animals-sxx18.txt
# animals-sxx19.txt
# animals-sxx190.txt
# animals-sxx20.txt
# animals-sxx21.txt
# animals-sxx22.txt
# animals-sxx23.txt
# animals-sxx24.txt
# animals-sxx25.txt
# animals-sxx26.txt
# animals-sxx27.txt
# animals-sxx28.txt
# animals-sxx29.txt
# animals-sxx30.txt
# animals-sxx32.txt
# animals-sxx33.txt
# animals-sxx34.txt
# animals-sxx35.txt
# animals-sxx36.txt
# animals-sxx38.txt
# animals-sxx39.txt
# animals-sxx41.txt
# animals-sxx42.txt
# animals-sxx62.txt
# animals.DS_Store.txt
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/5g/3v18ylv549z8z19q_rfdm_5c0000gq/T/ipykernel_7438/1332687051.py in <module>
#      16             with open(outfilename, 'w') as out:
#      17                 #Read the contents of the input file
# ---> 18                 voltext = f.read()
#      19                 #Do English NLP on the contents of the input file
#      20                 volner = nlp(voltext)
#
# ~/opt/anaconda3/envs/ansp/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x97 in position 99: invalid start byte
